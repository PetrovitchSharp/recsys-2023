# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
os.environ["OPENBLAS_NUM_THREADS"] = "1"  
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
from implicit.als import AlternatingLeastSquares
from rectools.metrics import MAP
from rectools.models import ImplicitALSWrapperModel
from rectools import Columns
from rectools.dataset import Dataset
from rectools.tools import UserToItemAnnRecommender
from pathlib import Path
import pandas as pd
import nmslib

# %% [markdown]
# ## Loading data

# %%
DATA_PATH = Path("../../data/03_primary")

# %%
users_features_full = pd.read_csv(DATA_PATH / 'au_featured_users_full.csv')
items_features_full = pd.read_csv(DATA_PATH / 'prepared_featured_items_full.csv')
interactions_full = pd.read_csv(DATA_PATH / 'au_interactions_full.csv')
items_descriptions = pd.read_csv(DATA_PATH / 'items_descriptions_cleared.csv')

# %%
full_dataset = Dataset.construct(
    interactions_df=interactions_full,
)

full_featured_dataset = Dataset.construct(
    interactions_df=interactions_full,
    user_features_df=users_features_full,
    cat_user_features=["sex", "age", "income"],
    item_features_df=items_features_full,
    cat_item_features=["genre", "content_type","age_rating","country","release_year_bin"],
)

# %%
# IDs from data preparation notebook
artificial_users_ids = [1097559, 1097561, 1097563]

# %% [markdown]
# ## Models training

# %% [markdown]
# All hyperparameters was taken from ALS notebook

# %%
K_RECOS = 10
RANDOM_STATE = 42
NUM_THREADS = 4

# %%
als_without_features = ImplicitALSWrapperModel(
    model = AlternatingLeastSquares(
        factors = 2,
        regularization = 0.03716111608869566,
        iterations = 42,
        use_cg = True,
        use_gpu = False,
        num_threads = NUM_THREADS,
        random_state = RANDOM_STATE
    )
)

als_without_features.fit(full_dataset)

# %%
als_with_features = ImplicitALSWrapperModel(
    model = AlternatingLeastSquares(
        factors = 3,
        regularization = 0.0018347283256986877,
        iterations = 13,
        use_cg = True,
        use_gpu = False,
        num_threads = NUM_THREADS,
        random_state = RANDOM_STATE
    ),
    fit_features_together = True,
)

als_with_features.fit(full_featured_dataset)

# %%
user_embeddings, item_embeddings = als_with_features.get_vectors()

# %%
ann = UserToItemAnnRecommender(
    user_vectors=user_embeddings,
    item_vectors=item_embeddings,
    user_id_map=full_featured_dataset.user_id_map,
    item_id_map=full_featured_dataset.item_id_map,
    index_init_params={
        'method' : 'hnsw',
        'space' : 'negdotprod',
        'data_type' : nmslib.DataType.DENSE_VECTOR
    }
)

# %%
ann.fit()

# %% [markdown]
# ## Checking recommendations

# %% [markdown]
# 1097559 - Mother with kid
#
# 1097561 - Superheroics fan
#
# 1097563 - Born in USSR

# %% [markdown]
# ### ALS without features

# %%
als_wo_features_reco = als_without_features.recommend(
    users=artificial_users_ids,
    dataset=full_dataset,
    k=K_RECOS,
    filter_viewed=True,
)

# %%
als_wo_features_reco = als_wo_features_reco.merge(items_descriptions, on='item_id')\
    .sort_values(by=['user_id','rank'])

# %% [markdown]
# #### Recos for mother with kid

# %%
als_wo_features_reco[:10]
# Out:
#     user_id  item_id     score  rank content_type  \
# 0   1097559     7626  0.205796     1         film
# 3   1097559    12173  0.202589     2         film
# 6   1097559    16166  0.192270     3         film
# 9   1097559     9728  0.187336     4         film
# 11  1097559     3182  0.187101     5         film
# 14  1097559    11237  0.183676     6         film
# 17  1097559    14317  0.178742     7         film
# 20  1097559    13018  0.167502     8         film
# 23  1097559     4457  0.167262     9         film
# 26  1097559     4436  0.164073    10         film
#
#                             title  release_year  \
# 0   Мстители: Война бесконечности        2018.0
# 3                 Мстители: Финал        2019.0
# 6                      Зверополис        2016.0
# 9               Гнев человеческий        2021.0
# 11         Ральф против Интернета        2018.0
# 14                    День города        2021.0
# 17                          Веном        2018.0
# 20              Король лев (2019)        2019.0
# 23            2067: Петля времени        2020.0
# 26            Ford против Ferrari        2019.0
#
#                                                genres            countries  \
# 0                    боевики, фантастика, приключения                  США
# 3                          боевики, драмы, фантастика                  США
# 6         приключения, мультфильм, детективы, комедии                  США
# 9                                   боевики, триллеры  Великобритания, США
# 11  мультфильм, приключения, фантастика, семейное,...                  США
# 14                                            комедии               Россия
# 17   популярное, фантастика, триллеры, боевики, ужасы                  США
# 20                     драмы, мультфильм, музыкальные                  США
# 23                                  драмы, фантастика            Австралия
# 26                                              драмы         США, Франция
#
#     age_rating
# 0         16.0
# 3         16.0
# 6          6.0
# 9         18.0
# 11         6.0
# 14        16.0
# 17        16.0
# 20         6.0
# 23        16.0
# 26        16.0

# %% [markdown]
# #### Recos for superheroics fan

# %%
als_wo_features_reco[10:20]
# Out:
#     user_id  item_id     score  rank content_type  \
# 28  1097561     7571  0.186155     1         film
# 1   1097561     7626  0.173646     2         film
# 4   1097561    12173  0.170421     3         film
# 7   1097561    16166  0.161210     4         film
# 12  1097561     3182  0.157422     5         film
# 18  1097561    14317  0.148785     6         film
# 15  1097561    11237  0.141144     7         film
# 21  1097561    13018  0.138874     8         film
# 27  1097561     4436  0.132068     9         film
# 24  1097561     4457  0.129889    10         film
#
#                             title  release_year  \
# 28                      100% волк        2020.0
# 1   Мстители: Война бесконечности        2018.0
# 4                 Мстители: Финал        2019.0
# 7                      Зверополис        2016.0
# 12         Ральф против Интернета        2018.0
# 18                          Веном        2018.0
# 15                    День города        2021.0
# 21              Король лев (2019)        2019.0
# 27            Ford против Ferrari        2019.0
# 24            2067: Петля времени        2020.0
#
#                                                genres           countries  \
# 28  мультфильм, приключения, семейное, фэнтези, ко...  Австралия, Бельгия
# 1                    боевики, фантастика, приключения                 США
# 4                          боевики, драмы, фантастика                 США
# 7         приключения, мультфильм, детективы, комедии                 США
# 12  мультфильм, приключения, фантастика, семейное,...                 США
# 18   популярное, фантастика, триллеры, боевики, ужасы                 США
# 15                                            комедии              Россия
# 21                     драмы, мультфильм, музыкальные                 США
# 27                                              драмы        США, Франция
# 24                                  драмы, фантастика           Австралия
#
#     age_rating
# 28         6.0
# 1         16.0
# 4         16.0
# 7          6.0
# 12         6.0
# 18        16.0
# 15        16.0
# 21         6.0
# 27        16.0
# 24        16.0

# %% [markdown]
# #### Recos for old man

# %%
als_wo_features_reco[20:]
# Out:
#     user_id  item_id     score  rank content_type  \
# 29  1097563     7571  0.000431     1         film
# 2   1097563     7626  0.000383     2         film
# 5   1097563    12173  0.000377     3         film
# 8   1097563    16166  0.000357     4         film
# 13  1097563     3182  0.000348     5         film
# 10  1097563     9728  0.000343     6         film
# 16  1097563    11237  0.000340     7         film
# 19  1097563    14317  0.000332     8         film
# 22  1097563    13018  0.000311     9         film
# 25  1097563     4457  0.000310    10         film
#
#                             title  release_year  \
# 29                      100% волк        2020.0
# 2   Мстители: Война бесконечности        2018.0
# 5                 Мстители: Финал        2019.0
# 8                      Зверополис        2016.0
# 13         Ральф против Интернета        2018.0
# 10              Гнев человеческий        2021.0
# 16                    День города        2021.0
# 19                          Веном        2018.0
# 22              Король лев (2019)        2019.0
# 25            2067: Петля времени        2020.0
#
#                                                genres            countries  \
# 29  мультфильм, приключения, семейное, фэнтези, ко...   Австралия, Бельгия
# 2                    боевики, фантастика, приключения                  США
# 5                          боевики, драмы, фантастика                  США
# 8         приключения, мультфильм, детективы, комедии                  США
# 13  мультфильм, приключения, фантастика, семейное,...                  США
# 10                                  боевики, триллеры  Великобритания, США
# 16                                            комедии               Россия
# 19   популярное, фантастика, триллеры, боевики, ужасы                  США
# 22                     драмы, мультфильм, музыкальные                  США
# 25                                  драмы, фантастика            Австралия
#
#     age_rating
# 29         6.0
# 2         16.0
# 5         16.0
# 8          6.0
# 13         6.0
# 10        18.0
# 16        16.0
# 19        16.0
# 22         6.0
# 25        16.0

# %% [markdown]
# ### ALS with features

# %%
als_with_features_reco = als_with_features.recommend(
    users=artificial_users_ids,
    dataset=full_featured_dataset,
    k=K_RECOS,
    filter_viewed=True,
)

# %%
als_with_features_reco = als_with_features_reco.merge(items_descriptions, on='item_id')\
    .sort_values(by=['user_id','rank'])

# %% [markdown]
# #### Recos for mother with kid

# %%
als_with_features_reco[:10]
# Out:
#     user_id  item_id     score  rank content_type  \
# 0   1097559    15297  0.450052     1       series
# 2   1097559     9728  0.267371     2         film
# 5   1097559     4151  0.261628     3       series
# 6   1097559    10440  0.238132     4       series
# 8   1097559     3734  0.211915     5         film
# 11  1097559     6809  0.186515     6         film
# 13  1097559    13865  0.162869     7         film
# 16  1097559    16166  0.098390     8         film
# 17  1097559    13018  0.097685     9         film
# 18  1097559      142  0.097565    10         film
#
#                            title  release_year  \
# 0                Клиника счастья        2021.0
# 2              Гнев человеческий        2021.0
# 5         Секреты семейной жизни        2021.0
# 6                    Хрустальный        2021.0
# 8   Прабабушка легкого поведения        2021.0
# 11                         Дуров        2021.0
# 13                      Девятаев        2021.0
# 16                    Зверополис        2016.0
# 17             Король лев (2019)        2019.0
# 18                          Маша        2020.0
#
#                                          genres            countries  \
# 0                              драмы, мелодрамы               Россия
# 2                             боевики, триллеры  Великобритания, США
# 5                                       комедии               Россия
# 6                           триллеры, детективы               Россия
# 8                                       комедии               Россия
# 11                               документальное               Россия
# 13                  драмы, военные, приключения               Россия
# 16  приключения, мультфильм, детективы, комедии                  США
# 17               драмы, мультфильм, музыкальные                  США
# 18                              драмы, триллеры               Россия
#
#     age_rating
# 0         18.0
# 2         18.0
# 5         18.0
# 6         18.0
# 8         16.0
# 11        16.0
# 13        12.0
# 16         6.0
# 17         6.0
# 18        16.0

# %% [markdown]
# #### Recos for superheroins fan

# %%
als_with_features_reco[10:20]
# Out:
#     user_id  item_id     score  rank content_type  \
# 3   1097561     9728  0.280038     1         film
# 14  1097561    13865  0.253946     2         film
# 19  1097561    14317  0.143034     3         film
# 9   1097561     3734  0.140239     4         film
# 20  1097561     7626  0.124257     5         film
# 21  1097561    11237  0.120163     6         film
# 23  1097561     2657  0.116982     7       series
# 24  1097561    12173  0.116811     8         film
# 25  1097561     6455  0.091032     9         film
# 12  1097561     6809  0.087945    10         film
#
#                             title  release_year  \
# 3               Гнев человеческий        2021.0
# 14                       Девятаев        2021.0
# 19                          Веном        2018.0
# 9    Прабабушка легкого поведения        2021.0
# 20  Мстители: Война бесконечности        2018.0
# 21                    День города        2021.0
# 23                     Подслушано        2021.0
# 24                Мстители: Финал        2019.0
# 25                          Альфа        2018.0
# 12                          Дуров        2021.0
#
#                                               genres            countries  \
# 3                                  боевики, триллеры  Великобритания, США
# 14                       драмы, военные, приключения               Россия
# 19  популярное, фантастика, триллеры, боевики, ужасы                  США
# 9                                            комедии               Россия
# 20                  боевики, фантастика, приключения                  США
# 21                                           комедии               Россия
# 23                                   драмы, триллеры               Россия
# 24                        боевики, драмы, фантастика                  США
# 25          драмы, популярное, семейное, приключения                  США
# 12                                    документальное               Россия
#
#     age_rating
# 3         18.0
# 14        12.0
# 19        16.0
# 9         16.0
# 20        16.0
# 21        16.0
# 23        16.0
# 24        16.0
# 25        12.0
# 12        16.0

# %% [markdown]
# #### Recos for old man

# %%
als_with_features_reco[20:]
# Out:
#     user_id  item_id     score  rank content_type  \
# 15  1097563    13865  0.295099     1         film
# 4   1097563     9728  0.240718     2         film
# 7   1097563    10440  0.107948     3       series
# 10  1097563     3734  0.093120     4         film
# 26  1097563     4740  0.085816     5         film
# 22  1097563    11237  0.083679     6         film
# 27  1097563     9996  0.074600     7       series
# 1   1097563    15297  0.071103     8       series
# 28  1097563      494  0.067429     9       series
# 29  1097563     3869  0.064190    10         film
#
#                            title  release_year  \
# 15                      Девятаев        2021.0
# 4              Гнев человеческий        2021.0
# 7                    Хрустальный        2021.0
# 10  Прабабушка легкого поведения        2021.0
# 26            Сахаров. Две жизни        2021.0
# 22                   День города        2021.0
# 27                         Немцы        2021.0
# 1                Клиника счастья        2021.0
# 28    Д'Артаньян и три мушкетера        1979.0
# 29            Воздушный извозчик        1943.0
#
#                                                genres            countries  \
# 15                        драмы, военные, приключения               Россия
# 4                                   боевики, триллеры  Великобритания, США
# 7                                 триллеры, детективы               Россия
# 10                                            комедии               Россия
# 26                                     документальное               Россия
# 22                                            комедии               Россия
# 27                                              драмы               Россия
# 1                                    драмы, мелодрамы               Россия
# 28  музыкальные, приключения, исторические, советс...                 СССР
# 29           советские, музыкальные, военные, комедии                 СССР
#
#     age_rating
# 15        12.0
# 4         18.0
# 7         18.0
# 10        16.0
# 26        16.0
# 22        16.0
# 27        16.0
# 1         18.0
# 28         0.0
# 29        12.0

# %% [markdown]
# ### ANN

# %%
ann_reco = ann.get_item_list_for_user_batch(
    user_ids=artificial_users_ids,
    top_n=K_RECOS
)

# %%
ann_recos_df = pd.DataFrame({
    Columns.User: artificial_users_ids,
    'reco': ann_reco
})

# %%
ann_recos_df = ann_recos_df\
    .set_index('user_id')\
    .explode('reco')\
    .rename(columns={
        'reco': 'item_id'
    }).reset_index()\
    .merge(items_descriptions, on='item_id')\
    .sort_values(by=['user_id'])

# %% [markdown]
# #### Recos for mother with kid

# %%
ann_recos_df[:10]
# Out:
#     user_id item_id content_type                         title  release_year  \
# 0   1097559   15297       series               Клиника счастья        2021.0
# 1   1097559    9728         film             Гнев человеческий        2021.0
# 3   1097559    4151       series        Секреты семейной жизни        2021.0
# 4   1097559   10440       series                   Хрустальный        2021.0
# 5   1097559    3734         film  Прабабушка легкого поведения        2021.0
# 7   1097559    6809         film                         Дуров        2021.0
# 8   1097559    7571         film                     100% волк        2020.0
# 9   1097559   13865         film                      Девятаев        2021.0
# 11  1097559    7582         film            Холодное сердце II        2019.0
# 12  1097559   16166         film                    Зверополис        2016.0
#
#                                                genres            countries  \
# 0                                    драмы, мелодрамы               Россия
# 1                                   боевики, триллеры  Великобритания, США
# 3                                             комедии               Россия
# 4                                 триллеры, детективы               Россия
# 5                                             комедии               Россия
# 7                                      документальное               Россия
# 8   мультфильм, приключения, семейное, фэнтези, ко...   Австралия, Бельгия
# 9                         драмы, военные, приключения               Россия
# 11                   фэнтези, мультфильм, музыкальные                  США
# 12        приключения, мультфильм, детективы, комедии                  США
#
#     age_rating
# 0         18.0
# 1         18.0
# 3         18.0
# 4         18.0
# 5         16.0
# 7         16.0
# 8          6.0
# 9         12.0
# 11         6.0
# 12         6.0

# %% [markdown]
# #### Recos for superheroins fan

# %%
ann_recos_df[10:20]
# Out:
#     user_id item_id content_type                            title  \
# 19  1097561   10942         film                         Мстители
# 18  1097561   12173         film                  Мстители: Финал
# 17  1097561    2657       series                       Подслушано
# 16  1097561   11237         film                      День города
# 15  1097561    7626         film    Мстители: Война бесконечности
# 14  1097561    6738         film  Человек-паук: Возвращение домой
# 13  1097561   14317         film                            Веном
# 10  1097561   13865         film                         Девятаев
# 6   1097561    3734         film     Прабабушка легкого поведения
# 2   1097561    9728         film                Гнев человеческий
#
#     release_year                                            genres  \
# 19        2012.0         боевики, фантастика, фэнтези, приключения
# 18        2019.0                        боевики, драмы, фантастика
# 17        2021.0                                   драмы, триллеры
# 16        2021.0                                           комедии
# 15        2018.0                  боевики, фантастика, приключения
# 14        2017.0      боевики, популярное, фантастика, приключения
# 13        2018.0  популярное, фантастика, триллеры, боевики, ужасы
# 10        2021.0                       драмы, военные, приключения
# 6         2021.0                                           комедии
# 2         2021.0                                 боевики, триллеры
#
#               countries  age_rating
# 19                  США        12.0
# 18                  США        16.0
# 17               Россия        16.0
# 16               Россия        16.0
# 15                  США        16.0
# 14                  США        16.0
# 13                  США        16.0
# 10               Россия        12.0
# 6                Россия        16.0
# 2   Великобритания, США        18.0

# %% [markdown]
# #### Recos for old man

# %%
ann_recos_df[20:]
# Out:
#     user_id item_id content_type                       title  release_year  \
# 20  1097563     494       series  Д'Артаньян и три мушкетера        1979.0
# 21  1097563    1012         film         Свадьба в Малиновке        1967.0
# 22  1097563    3869         film          Воздушный извозчик        1943.0
# 23  1097563   16394         film          Не плачь, девчонка        1976.0
# 24  1097563    1538         film                 Князь Игорь        1969.0
# 25  1097563   13588         film              Волшебная сила        1970.0
# 26  1097563    6401         film                Король-олень        1970.0
# 27  1097563    7449         film                 Свой парень        1974.0
# 28  1097563   14160         film               Ключи от неба        1965.0
# 29  1097563   15899         film       На войне как на войне        1968.0
#
#                                                genres countries  age_rating
# 20  музыкальные, приключения, исторические, советс...      СССР         0.0
# 21  музыкальные, советские, мелодрамы, семейное, к...      СССР        12.0
# 22           советские, музыкальные, военные, комедии      СССР        12.0
# 23          семейное, советские, музыкальные, комедии      СССР        12.0
# 24  музыкальные, драмы, исторические, советские, ф...      СССР         0.0
# 25          советские, семейное, музыкальные, комедии      СССР         0.0
# 26  музыкальные, советские, семейное, фэнтези, ком...      СССР         0.0
# 27         мелодрамы, советские, музыкальные, комедии      СССР        16.0
# 28         мелодрамы, советские, музыкальные, комедии      СССР        12.0
# 29                   исторические, советские, военные      СССР        12.0

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ALS keeps trying and trying to push popular items into the recommendations. But ANN modification seems to have caught a little more context and gave us more relevant recommendations (although it duplicated some of the aitems)
